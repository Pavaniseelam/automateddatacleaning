# %%
pip install py-AutoClean
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.1 MB/s eta 0:00:00
# ...
#   Created wheel for py-AutoClean: filename=py_AutoClean-1.1.3-py3-none-any.whl size=10273 sha256=da3841e02faf943e2baa52f2b284bddadbc4068cb9ec193fa5b584fe8a93cef2
#   Stored in directory: /root/.cache/pip/wheels/90/13/2b/023a24f8979c2b917dded511572b55f79d5b3a848a3e6646d1
# Successfully built py-AutoClean
# ...

# %%
from AutoClean import AutoClean

# %%
import pandas as pd

dataset = pd.read_csv(r"C:/Users/pavan/Desktop/dataset/Air_Quality.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-2cf46f7cab08> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 dataset = pd.read_csv(r"C:/Users/pavan/Desktop/dataset/Air_Quality.csv")
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ea7c30a0-7852-4fda-a9f7-261d00e3811c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea7c30a0-7852-4fda-a9f7-261d00e3811c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pipeline = AutoClean(dataset)
cleaned_data = pipeline.output
# Out:
# AutoClean process completed in 0.119753 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', outliers='auto', encode_categ=['onehot'])
# Out:
# AutoClean process completed in 0.020334 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', duplicates='auto')
# Out:
# AutoClean process completed in 0.015629 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', missing_num='mean')  # Options: 'auto', 'knn', 'mean', 'median', etc.
# Out:
# AutoClean process completed in 0.01599 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', missing_categ='most_frequent')  # Options: 'logreg', 'knn', etc.
# Out:
# AutoClean process completed in 0.023702 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', encode_categ=['onehot'])  # Options: 'label'
# Out:
# AutoClean process completed in 0.016201 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', extract_datetime='D')  # Options: 'M', 'Y', 'h', 'm', 's'
# Out:
# AutoClean process completed in 0.020561 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', outliers='delete')  # Options: 'winz', 'delete'
# Out:
# AutoClean process completed in 0.018446 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, mode='manual', outlier_param=2.0)  # Default: 1.5
# Out:
# AutoClean process completed in 0.011294 seconds
# Logfile saved to: /content/autoclean.log

# %%
pipeline = AutoClean(dataset, logfile=True)  # Options: True, False
# Out:
# AutoClean process completed in 0.023567 seconds
# Logfile saved to: /content/autoclean.log

# %%
cleaned_data = pipeline.output

# %%
cleaned_data = pipeline.output
print(cleaned_data)  # This will display the cleaned DataFrame
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.0           5.2          2.3  virginica
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
#
#      species_setosa  species_versicolor  species_virginica
# 0              True               False              False
# ...
